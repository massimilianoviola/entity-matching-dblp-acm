# %%
import pandas as pd
import numpy as np
import html
import string
from sklearn.model_selection import train_test_split

np.random.seed(42)

# %%
def preprocess_titles(df):
    return (
        df.title.str.lower() # normalize to lower case
                .str.translate(str.maketrans(string.punctuation, ' ' * len(string.punctuation))) # replace punctuation characters with spaces
                .map(lambda x: ' '.join(x.split())) # remove double spaces
    )

def preprocess_authors(df):
    return (
         df.loc[df.authors.notna(), 'authors'] # select only rows with some authors
            .map(lambda x: html.unescape(x)) # convert html escaped latin characters
            .map(lambda x: ', '.join(sorted(x.split(', ')))) # sort authors alphabetically
    )

# %%
df_true = pd.read_csv('DBLP-ACM/DBLP-ACM_perfectMapping.csv')
df_true
# Out:
#                             idDBLP   idACM
# 0       conf/sigmod/SlivinskasJS01  375678
# 1        conf/sigmod/ChaudhuriDN01  375694
# 2          conf/sigmod/RinfretOO01  375669
# 3         conf/sigmod/BreunigKKS01  375672
# 4        conf/sigmod/JagadishJOT01  375687
# ...                            ...     ...
# 2219      journals/sigmod/Scholl01  604275
# 2220  journals/sigmod/Rosneblatt94  190649
# 2221   journals/sigmod/Winslett02b  601871
# 2222  journals/sigmod/Labrinidis01  604283
# 2223    journals/sigmod/Winslett03  640999
#
# [2224 rows x 2 columns]

# %%
dfa = pd.read_csv('DBLP-ACM/ACM.csv')
dfa.loc[:, 'title'] = preprocess_titles(dfa)
dfa.loc[dfa.authors.notna(), 'authors'] = preprocess_authors(dfa)
dfa
# Out:
#           id                                              title  \
# 0     304586  the wasa2 object oriented workflow management ...
# 1     304587  a user centered interface for querying distrib...
# 2     304589  world wide database integrating the web corba ...
# 3     304590           xml based information mediation with mix
# 4     304582  the ccube constraint object oriented database ...
# ...      ...                                                ...
# 2289  672977          dual buffering strategies in object bases
# 2290  950482                                    guest editorial
# 2291  672980  graphdb modeling and querying graphs in databases
# 2292  945741  review of the data warehouse toolkit the compl...
# 2293  672979      bulk loading into an oodb a performance study
#
#                                                 authors  \
# 0                       Gottfried Vossen, Mathias Weske
# 1                     Isabel F. Cruz, Kimberly M. James
# 2     Athman Bouguettaya, Boualem Benatallah, James ...
# 3     Amarnath Gupta, Bertram Ludäscher, Chaitan Bar...
# 4     Alexander Brodsky, Jia Chen, Paval A. Exarkhop...
# ...                                                 ...
# 2289                     Alfons Kemper, Donald Kossmann
# 2290  Philip A. Bernstein, Raghu Ramakrishnan, Yanni...
# 2291                                Ralf Hartmut Güting
# 2292                              Alexander A. Anisimov
# 2293               Janet L. Wiener, Jeffrey F. Naughton
#
#                                                   venue  year
# 0        International Conference on Management of Data  1999
# 1        International Conference on Management of Data  1999
# 2        International Conference on Management of Data  1999
# 3        International Conference on Management of Data  1999
# 4        International Conference on Management of Data  1999
# ...                                                 ...   ...
# 2289                              Very Large Data Bases  1994
# 2290  The VLDB Journal &mdash; The International Jou...  2003
# 2291                              Very Large Data Bases  1994
# 2292                                 ACM SIGMOD Record   2003
# 2293                              Very Large Data Bases  1994
#
# [2294 rows x 5 columns]

# %%
dfb = pd.read_csv('DBLP-ACM/DBLP2.csv', encoding='latin_1')
dfb.loc[:, 'title'] = preprocess_titles(dfb)
dfb.loc[dfb.authors.notna(), 'authors'] = preprocess_authors(dfb)
dfb
# Out:
#                                   id  \
# 0           journals/sigmod/Mackay99
# 1               conf/vldb/PoosalaI96
# 2            conf/vldb/PalpanasSCP02
# 3             conf/vldb/GardarinGT96
# 4                  conf/vldb/HoelS95
# ...                              ...
# 2611          journals/tods/KarpSP03
# 2612               conf/vldb/LimWV03
# 2613  journals/tods/ChakrabartiKMP02
# 2614     journals/sigmod/Snodgrass01
# 2615                 conf/vldb/LiM01
#
#                                                   title  \
# 0     semantic integration of environmental models f...
# 1     estimation of query result distribution and it...
# 2     incremental maintenance for non distributive a...
# 3     cost based selection of path expression proces...
# 4     benchmarking spatial join operations with spat...
# ...                                                 ...
# 2611  a simple algorithm for finding frequent elemen...
# 2612  sash a self adaptive histogram set for dynamic...
# 2613  locally adaptive dimensionality reduction for ...
# 2614                                    chair s message
# 2615  indexing and querying xml data for regular pat...
#
#                                                 authors  \
# 0                                       D. Scott Mackay
# 1                Viswanath Poosala, Yannis E. Ioannidis
# 2     Hamid Pirahesh, Richard Sidle, Roberta Cochran...
# 3     Georges Gardarin, Jean-Robert Gruser, Zhao-Hui...
# 4                             Erik G. Hoel, Hanan Samet
# ...                                                 ...
# 2611  Christos H. Papadimitriou, Richard M. Karp, Sc...
# 2612        Jeffrey Scott Vitter, Lipyeow Lim, Min Wang
# 2613  Eamonn J. Keogh, Kaushik Chakrabarti, Michael ...
# 2614                               Richard T. Snodgrass
# 2615                          Bongki Moon, Quanzhong Li
#
#                           venue  year
# 0                 SIGMOD Record  1999
# 1                          VLDB  1996
# 2                          VLDB  2002
# 3                          VLDB  1996
# 4                          VLDB  1995
# ...                         ...   ...
# 2611  ACM Trans. Database Syst.  2003
# 2612                       VLDB  2003
# 2613  ACM Trans. Database Syst.  2002
# 2614              SIGMOD Record  2001
# 2615                       VLDB  2001
#
# [2616 rows x 5 columns]

# %%
def merge_dataframes(dfa, dfb, df_true, match_number_of_false=False):
    df_match = (
        dfa.merge(df_true, left_on="id", right_on="idACM")
           .merge(dfb, left_on="idDBLP", right_on="id")
    ) # take only matches in the two data frames
    df_match["label"] = True # mark these rows as matches

    dfa_no_match = df_match[["id_x"]].merge(dfa, how="right", left_on="id_x", right_on="id") # join with the matches
    dfa_no_match.drop(dfa_no_match[~dfa_no_match["id_x"].isna()].index, inplace=True) # drop all rows, which have a match
    dfa_no_match.drop(["id_x"], axis=1, inplace=True) # drop the column used for join
    dfa_no_match["order"] = np.arange(len(dfa_no_match)) # create new column to join with 'dfb'

    dfb_no_match = df_match[["id_y"]].merge(dfb, how="right", left_on="id_y", right_on="id") # join with the matches
    dfb_no_match.drop(dfb_no_match[~dfb_no_match["id_y"].isna()].index, inplace=True) # drop all rows, which have a match
    dfb_no_match.drop(["id_y"], axis=1, inplace=True) # drop the column used for join
    dfb_no_match["order"] = np.arange(len(dfb_no_match)) # create new column to join with 'dfa'

    df_no_match = dfa_no_match.merge(dfb_no_match, on="order") # join non matches with inner join, some records from longer data frame are ignored 
    df_no_match.drop(["order"], axis=1, inplace=True) # drop the column used for join
    df_no_match["label"] = False # mark these rows as not matching

    df = pd.concat([df_match, df_no_match]) # append matches and non matches
    df.drop(["idDBLP", "idACM", "id_x", "id_y"], axis=1, inplace=True) # drop unnecessary columns

    if match_number_of_false: # add non matches to the data frame so there are 50/50 matches/non matches
        add_no_match_count = len(df[df["label"] == True]) - len(df[df["label"] == False])

        if add_no_match_count > 0: # there are more matches then non matches
            dfa_with_connection = dfa.merge(df_true, left_on="id", right_on="idACM") # add the connection table, so matches/non matches can be found
            dfa_with_connection["order"] = np.random.choice(len(dfa_with_connection), len(dfa_with_connection), replace=False) # random order to join randomly
            dfb_copy = dfb.copy() # copy so the function doesn't have side effects
            dfb_copy["order"] = np.arange(len(dfb_copy)) # column to join with 'dfa_with_connection'
            df_no_match = dfa_with_connection.merge(dfb_copy, left_on="order", right_on="order") # join on the order
            df_no_match[df_no_match["idACM"] != df_no_match["id_y"]] # remove matches
            df_no_match = df_no_match[:add_no_match_count] # take up to the needed number of non matches
            df_no_match["label"] = False # mark them as non matches
            df_no_match.drop(["idDBLP", "idACM", "id_x", "id_y", "order"], axis=1, inplace=True) # drop unnecessary columns 
            df = pd.concat([df, df_no_match]) # add them to the final data frame

    return df.sample(frac=1) # shuffel rows of the data frame

# %%
NUM_OF_CROSS_VALIDATIONS = 5

dfa_train, dfa_test = train_test_split(dfa, test_size=1/(NUM_OF_CROSS_VALIDATIONS + 1), stratify=dfa[["year"]], random_state=42)
dfb_train, dfb_test = train_test_split(dfb, test_size=1/(NUM_OF_CROSS_VALIDATIONS + 1), stratify=dfb[["year"]], random_state=42)

df_train_validation = merge_dataframes(dfa_train, dfb_train, df_true, True) # ensure there is same number of positive and negative training samples
df_test = merge_dataframes(dfa_test, dfb_test, df_true)

y_test = df_test.pop("label")
X_test = df_test

train_validation_data = []
for _ in range(NUM_OF_CROSS_VALIDATIONS):
    data_dict = {}
    df_train, df_validation = train_test_split(df_train_validation, test_size=1/NUM_OF_CROSS_VALIDATIONS, stratify=df_train_validation[["label"]])
    data_dict["y_train"] = df_train.pop("label")
    data_dict["y_validation"] = df_validation.pop("label")
    data_dict["X_train"] = df_train
    data_dict["X_validation"] = df_validation
    train_validation_data.append(data_dict)

# %%
train_validation_data[0]["X_train"]
# Out:
#                                                 title_x  \
# 709              interviewing during a tight job market
# 509           space optimization in deductive databases
# 727   towards on line analytical mining in large dat...
# 426   efficient evaluation of queries in a mediator ...
# 1417      temporal aggregation in active database rules
# ...                                                 ...
# 238                      describing semistructured data
# 19    a general technique for querying xml documents...
# 838   efficiently publishing relational data as xml ...
# 266       approximate join processing over data streams
# 1205           xml based information mediation with mix
#
#                                               authors_x  \
# 709                          Qiong Luo, Zachary G. Ives
# 509   Divesh Srivastava, Jeffrey F. Naughton, Raghu ...
# 727                                          Jiawei Han
# 426   Laura Bright, Louiqa Raschid, Maria Esther Vid...
# 1417                     Carlo Zaniolo, Iakovos Motakis
# ...                                                 ...
# 238                                       Luca Cardelli
# 19    Efstratios Viglas, Eugene Shekita, Igor Tatari...
# 838   Berthold Reinwald, Bruce G. Lindsay, Eugene J....
# 266    Abhinandan Das, Johannes Gehrke, Mirek Riedewald
# 1205  Amarnath Gupta, Bertram Ludäscher, Chaitan Bar...
#
#                                              venue_x  year_x  \
# 709                               ACM SIGMOD Record     2002
# 509     ACM Transactions on Database Systems (TODS)     1995
# 727                               ACM SIGMOD Record     1998
# 426   International Conference on Management of Data    2002
# 1417  International Conference on Management of Data    1997
# ...                                              ...     ...
# 238                               ACM SIGMOD Record     2001
# 19                                ACM SIGMOD Record     2001
# 838                            Very Large Data Bases    2000
# 266   International Conference on Management of Data    2003
# 1205  International Conference on Management of Data    1999
#
#                                                 title_y  \
# 709   xml and information retrieval a sigir 2000 wor...
# 509           space optimization in deductive databases
# 727   parallel query scheduling and optimization wit...
# 426   providing dynamic security control in a federa...
# 1417      temporal aggregation in active database rules
# ...                                                 ...
# 238             data management for pervasive computing
# 19               a database platform for bioinformatics
# 838   efficiently publishing relational data as xml ...
# 266       approximate join processing over data streams
# 1205           xml based information mediation with mix
#
#                                               authors_y  \
# 709          Aya Soffer, David Carmel, Yoëlle S. Maarek
# 509   Divesh Srivastava, Jeffrey F. Naughton, Raghu ...
# 727           Minos N. Garofalakis, Yannis E. Ioannidis
# 426          N. B. Idris, R. F. Churchhouse, W. A. Gray
# 1417                     Carlo Zaniolo, Iakovos Motakis
# ...                                                 ...
# 238   Michael J. Franklin, Mitch Cherniack, Stanley ...
# 19                                   Sandeepan Banerjee
# 838   Berthold Reinwald, Bruce G. Lindsay, Eugene J....
# 266    Abhinandan Das, Johannes Gehrke, Mirek Riedewald
# 1205  Amarnath Gupta, Bertram Ludäscher, Chaitanya K...
#
#                         venue_y  year_y
# 709               SIGMOD Record    2001
# 509   ACM Trans. Database Syst.    1995
# 727                        VLDB    1997
# 426                        VLDB    1994
# 1417          SIGMOD Conference    1997
# ...                         ...     ...
# 238                        VLDB    2001
# 19                         VLDB    2000
# 838                        VLDB    2000
# 266           SIGMOD Conference    2003
# 1205          SIGMOD Conference    1999
#
# [2478 rows x 8 columns]

# %%
train_validation_data[0]["y_train"]
# Out:
# 709     False
# 509      True
# 727     False
# 426     False
# 1417     True
#         ...
# 238     False
# 19      False
# 838      True
# 266      True
# 1205     True
# Name: label, Length: 2478, dtype: bool

# %%
train_validation_data[0]["X_validation"]
# Out:
#                                                 title_x  \
# 902                                 the third manifesto
# 585   distributed hypertext resource discovery throu...
# 68    next generation database systems won t work wi...
# 873   i3 intelligent interactive investigation of ol...
# 2     curio a novel solution for efficient storage a...
# ...                                                 ...
# 1432  performance issues in incremental warehouse ma...
# 688             a critique of ansi sql isolation levels
# 331   local dimensionality reduction a new approach ...
# 1072                    oodb indexing by class division
# 1180                high concurrency locking in r trees
#
#                                               authors_x  \
# 902                             C. J. Date, Hugh Darwen
# 585   Byron Dom, Martin van den Berg, Soumen Chakrab...
# 68                                      John Mylopoulos
# 873                      Gayatri Sathe, Sunita Sarawagi
# 2     Anindya Datta, Helen M. Thomas, Krithi Ramamri...
# ...                                                 ...
# 1432  Hector Garcia-Molina, Jennifer Widom, Jun Yang...
# 688   Elizabeth O'Neil, Hal Berenson, Jim Gray, Jim ...
# 331                Kaushik Chakrabarti, Sharad Mehrotra
# 1072             Paris C. Kanellakis, Sridhar Ramaswamy
# 1180                    Douglas Banks, Marcel Kornacker
#
#                                              venue_x  year_x  \
# 902                               ACM SIGMOD Record     1995
# 585                            Very Large Data Bases    1999
# 68    International Conference on Management of Data    1998
# 873   International Conference on Management of Data    2000
# 2                              Very Large Data Bases    1999
# ...                                              ...     ...
# 1432                           Very Large Data Bases    2000
# 688   International Conference on Management of Data    1995
# 331                            Very Large Data Bases    2000
# 1072  International Conference on Management of Data    1995
# 1180                           Very Large Data Bases    1995
#
#                                                 title_y  \
# 902                                 the third manifesto
# 585   distributed hypertext resource discovery throu...
# 68    improving business process quality through exc...
# 873   an ontological analysis of the relationship co...
# 2     topaz a cost based rule driven multi phase par...
# ...                                                 ...
# 1432  performance issues in incremental warehouse ma...
# 688     are quorums an alternative for data replication
# 331   local dimensionality reduction a new approach ...
# 1072       a foundation for multi dimensional databases
# 1180                high concurrency locking in r trees
#
#                                               authors_y  \
# 902                             C. J. Date, Hugh Darwen
# 585   Byron Dom, Martin van den Berg, Soumen Chakrab...
# 68    Daniela Grigori, Fabio Casati, Ming-Chien Shan...
# 873                Ron Weber, Veda C. Storey, Yair Wand
# 2                       Bernhard Mitschang, Clara Nippl
# ...                                                 ...
# 1432  Hector Garcia-Molina, Jennifer Widom, Jun Yang...
# 688   Bettina Kemme, Gustavo Alonso, Marta Patiño-Ma...
# 331                Kaushik Chakrabarti, Sharad Mehrotra
# 1072                Laks V. S. Lakshmanan, Marc Gyssens
# 1180                    Douglas Banks, Marcel Kornacker
#
#                         venue_y  year_y
# 902               SIGMOD Record    1995
# 585                        VLDB    1999
# 68                         VLDB    2001
# 873   ACM Trans. Database Syst.    1999
# 2                          VLDB    1998
# ...                         ...     ...
# 1432                       VLDB    2000
# 688   ACM Trans. Database Syst.    2003
# 331                        VLDB    2000
# 1072                       VLDB    1997
# 1180                       VLDB    1995
#
# [620 rows x 8 columns]

# %%
train_validation_data[0]["y_validation"]
# Out:
# 902      True
# 585      True
# 68      False
# 873     False
# 2       False
#         ...
# 1432     True
# 688     False
# 331      True
# 1072    False
# 1180     True
# Name: label, Length: 620, dtype: bool
